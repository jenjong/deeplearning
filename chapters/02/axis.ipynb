# %% [markdown]
# # 축의 조정과 텍스트
#  <!-- 2-2 -->

# %% [markdown]
# 1. numpy의 설치
# - 가상환경의 선택
# - conda install numpy
#     Anaconda 설치 경로의 확인:
#
# 2. 벡터와 행렬의 생성
#     numpy.array
# (1) 리스트를 이용한 벡터의 생성
# (2) numpy.zeros(), numpy.ones()
# (3) numpy.repeat()
# (4) 리스트를 이용한 행렬의 생성
# (5) 대각행렬 생성하기 (numpy.diag())
#
# 3. 벡터와 행렬의 형태 변환
# (1) shape 이해하기
# (2) reshape 이해하기 (order = ‘C’ or ‘F’)
# ----

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#%%
# 2-2-1 (scatter)
# 한 개의 점을 찍어보자. 
t = np.arange(0., 5., 0.2)
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(t,t, color ='red', marker = '.')
#%%
# grid의 추가
t = np.arange(0., 5., 0.2)
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(t,t, color ='red', marker = '.')
ax.grid(True)
#%%
#grid 조정
t = np.arange(0., 5., 0.2)
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(t,t, color ='red', marker = '.')
ax.grid(True)
ax.set_xticks(np.arange(0,5,0.5))
ax.set_title('scatter plot')

#%%
#grid 조정
t = np.arange(0., 5., 0.2)
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(t,t, color ='red', marker = '.', label='red_p')
ax.grid(True)
ax.set_xticks(np.arange(0,5,0.5))
ax.set_title('scatter plot')
ax.legend()

#%%
# legend 위치 변경
# legend(loc=)
# upper left', 'upper right', 'lower left', 'lower right',
# best, center, center right

t = np.arange(0., 5., 0.2)
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(t,t, color ='red', marker = '.', label='red_p')
ax.grid(True)
ax.set_xticks(np.arange(0,5,0.5))
ax.set_title('scatter plot')
ax.legend(loc='lower right')


#%%
# 한 개의
t = np.arange(0., 5., 0.2)
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(t,t, color ='red', marker = '.')

ax.scatter(t,t**2, color ='lightblue', marker = '+')
ax.scatter(t,t**3, color ='green', marker = '^')
# %%
t = np.arange(0., 5., 0.2)
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(t,t, color ='red', linestyle = '--')
ax.plot(t,t**2, color ='lightblue', linestyle = '-.')
ax.plot(t,t**3, color ='green', linestyle = '-')





#%%
# 2-2-2 (histogram)
x = np.random.normal(0,1,size =2500)
n, bins, patches = plt.hist(x, bins=50, density=True, facecolor='tab:green', alpha=0.75)
#%%
n, bins, patches = plt.hist(x, bins=50, density=True, facecolor='tab:green', edgecolor = 'white', alpha=0.75)
plt.xlabel('x')
plt.ylabel('Probability')
plt.title('standard normal')
plt.text(-0.5, .1, r'$\mu=0,\ \sigma=1$')
plt.xlim(-4, 4)
plt.ylim(0, 0.5)
plt.grid(True)

#%%
plt.hist(x, bins=2, density=True, facecolor='tab:green', alpha=0.75)
plt.title('standard normal')

#%%
plt.hist(x, bins=2500, density=True, facecolor='tab:green', alpha=0.75)
plt.title('standard normal')

#%%
x = np.random.normal(0,1,size =2500)
#%%
fig, ax = plt.subplots()
ax.hist(x, bins = 50, density=True, facecolor='tab:green', alpha=0.75)
ax.set_xlabel('x')
ax.set_ylabel('Probability')
ax.set_title('standard normal')
ax.set_xlim(-4,4)
ax.grid(True,'major', 'y')
#%%
# 동시비교: 2개 데이터의 표시 
a = np.random.normal(0, 3, 1000)
b = np.random.normal(2, 4, 900)
fig, ax = plt.subplots()
ax.hist(a, 50, density = True, alpha = 0.5, label=r'N(0,$3^2$)')
ax.hist(b, 50, density = True, alpha = 0.5, label=r'N(2,$4^2$)')
ax.legend(loc='upper left')
ax.set_title("two histogramss")

#
# 수평비교
fig, ax = plt.subplots(1,2)
ax[0].hist(a, 50, density = True, alpha = 0.5, label=r'N(0,$3^2$)')
ax[1].hist(b, 50, density = True, alpha = 0.5, label=r'N(2,$4^2$)')
ax[0].legend(loc='upper left')
ax[1].legend(loc='upper left')

# 수직비교1
fig, ax = plt.subplots(2,1)
ax[0].hist(a, 50, density = True, alpha = 0.5, label=r'N(0,$3^2$)')
ax[1].hist(b, 50, density = True, alpha = 0.5, label=r'N(2,$4^2$)')
ax[0].legend(loc='upper left')
ax[1].legend(loc='upper left')

# 수직비교2
fig, ax = plt.subplots(2,1)
ax[0].hist(a, 50, density = True, alpha = 0.5, label=r'N(0,$3^2$)')
ax[1].hist(b, 50, density = True, alpha = 0.5, label=r'N(2,$4^2$)')
ax[0].legend(loc='upper left')
ax[1].legend(loc='upper left')
ax[0].set_xlim(-10,15)
ax[1].set_xlim(-10,15)




#%%
# 2-2-3
# boxplot
a = np.random.normal(0, 1, 1000)
b = np.random.normal(5, 1, 200)
fig, ax = plt.subplots()
ax.boxplot([a,b], labels=["A","B"], )

#%%
# mixture 분포
a = np.random.normal(0, 1, 1000)
b = np.random.normal(5, 1, 200)
x = np.concatenate([a,b])

fig, ax = plt.subplots()
ax.hist(x, bins = 40)
ax.set_title('mixture dist')

#%%
fig, ax = plt.subplots()
ax.boxplot(x, labels='x')
ax.set_title('mixture dist')

#%%
fig, ax = plt.subplots()
ax.violinplot(x)
ax.set_title('mixture dist')
#%%
fig, ax = plt.subplots()
ax.violinplot([x,a,b])
#%%
# labeling의 문제점 해결
fig, ax = plt.subplots()
ax.violinplot([x,a,b])
ax.set_title('mixture dist')
ax.set_xticks([1,2,3])
ax.set_xticklabels(["mixture", 'a', 'b'])

#%%
fig, ax = plt.subplots()
ax.violinplot([x,a,b])
ax.set_title('mixture dist')
ax.set_xticks([1,2,3])
ax.set_xticklabels(["mixture", 'a', 'b'])
# 응용 ax.scatter 에 데이터 파일을 지정 (dictionary 형태)
# Out:
# [Text(1, 0, 'mixture'), Text(2, 0, 'a'), Text(3, 0, 'b')]
